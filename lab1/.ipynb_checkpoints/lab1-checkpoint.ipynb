# %%
import numpy as np
import scipy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
headers = ["Дата", "Глубина манометра", "Dшт", "Руст", "Рзаб", "Pлин", "Руст", "Рзаб", "Рлин", "Туст", "Тна шлейфе", "Тзаб", "Tлин", "Дебит газа", "Дебит ст. конд.", "Дебит воды", "Дебит смеси", "Дебит гааз", "Дебит кон нестабильный", "Дебит воды", "Нэф", "Рпл. Тек (послед точка на КВД)", "Рпл. Тек (Расчет по КВД)", "Рпл. Тек (Карноухов)", "Pсб", "Pсб", "Ro_g", "Ro_c", "Ro_w", "Удельная плотность газа", "G_total", "КГФ", "КГФ_1"]
headers1 = ["Дата", "Глубина манометра", "Dшт", "Руст", "Рзаб", "Pлин", "Руст", "Рзаб", "Рлин", "Туст", "Тна шлейфе", "Тзаб", "Tлин", "Дебит газа", "Дебит ст. конд.", "Дебит воды", "Дебит смеси", "Дебит гааз", "Дебит кон нестабильный", "Дебит воды", "Нэф", "Рпл. Тек (послед точка на КВД)", "Рпл. Тек (Расчет по КВД)", "Рпл. Тек (Карноухов)", "Pсб", "Pсб", "Ro_g", "Ro_c", "Ro_w", "Удельная плотность газа", "G_total", "КГФ"]
from termcolor import colored
df = pd.read_excel('ID_data_mass_18122012.xlsx', index_col= 0, sheet_name='VU', skiprows=2)
df.columns = headers
df['КГФ_1'] = df['КГФ_1'].apply(lambda x: x*1000)
df['КГФ'] = df['КГФ'].mask(df['КГФ'].isna(), df['КГФ_1'])
del df['КГФ_1']
df.dropna(axis = 0, subset = ['G_total','КГФ'], how = 'all', inplace = True)
df=df.replace({'-':np.NaN})
df=df.replace({'не спускался':np.NaN})
df.dropna(thresh=55 ,axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93 entries, 804 to 22503
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Дата                            93 non-null     datetime64[ns]
#  1   Глубина манометра               90 non-null     float64
#  2   Dшт                             93 non-null     float64
#  3   Руст                            93 non-null     float64
#  4   Рзаб                            90 non-null     float64
#  5   Pлин                            93 non-null     float64
#  6   Руст                            93 non-null     float64
#  7   Рзаб                            90 non-null     float64
#  8   Рлин                            93 non-null     float64
#  9   Туст                            93 non-null     float64
#  10  Тна шлейфе                      60 non-null     float64
#  11  Тзаб                            90 non-null     float64
# ...

# %%
for column in df.columns:
    df[column] = df[column].fillna((df[column].mean()))
df.info()
df_copy = df.copy()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93 entries, 804 to 22503
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Дата                            93 non-null     datetime64[ns]
#  1   Глубина манометра               93 non-null     float64
#  2   Dшт                             93 non-null     float64
#  3   Руст                            93 non-null     float64
#  4   Рзаб                            93 non-null     float64
#  5   Pлин                            93 non-null     float64
#  6   Руст                            93 non-null     float64
#  7   Рзаб                            93 non-null     float64
#  8   Рлин                            93 non-null     float64
#  9   Туст                            93 non-null     float64
#  10  Тна шлейфе                      93 non-null     float64
#  11  Тзаб                            93 non-null     float64
# ...

# %%
del df_copy['Дата']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from rfpimp import permutation_importances

y_train = df_copy['КГФ']
del df_copy['КГФ']
y_train1 = df_copy['G_total']
del df_copy['G_total']
X_train = df_copy
rf = RandomForestRegressor(n_estimators = 100,
                           n_jobs = -1,
                           oob_score = True,
                           bootstrap = True,
                           random_state = 42)
rf.fit(X_train, y_train)

def r2(rf, X_train, y_train):
    return r2_score(y_train, rf.predict(X_train))

perm_imp_rfpimp = permutation_importances(rf, X_train, y_train, r2)
print(perm_imp_rfpimp)
# Out:
#                                 Importance
# Feature
# Рпл. Тек (послед точка на КВД)    0.452187
# Туст                              0.062994
# Рзаб                              0.057034
# Дебит гааз                        0.055220
# Рпл. Тек (Расчет по КВД)          0.049384
# Руст                              0.046972
# Рзаб                              0.046605
# Ro_c                              0.033500
# Руст                              0.031595
# Дебит воды                        0.014695
# Дебит воды                        0.013588
# Глубина манометра                 0.011092
# Тна шлейфе                        0.010649
# Рпл. Тек (Карноухов)              0.010596
# Дебит кон нестабильный            0.008773
# Тзаб                              0.008402
# Pсб                               0.006814
# Дебит газа                        0.006565
# Нэф                               0.006189
# Рлин                              0.005850
# Pлин                              0.005679
# ...

# %%
rf = RandomForestRegressor(n_estimators = 100,
                           n_jobs = -1,
                           oob_score = True,
                           bootstrap = True,
                           random_state = 42)
rf.fit(X_train, y_train1)

def r2(rf, X_train, y_train1):
    return r2_score(y_train1, rf.predict(X_train))

perm_imp_rfpimp = permutation_importances(rf, X_train, y_train1, r2)
print(perm_imp_rfpimp)
# Out:
#                                   Importance
# Feature
# Дебит ст. конд.                 1.874840e-01
# Тзаб                            1.448096e-01
# Туст                            5.514666e-02
# Дебит смеси                     4.130408e-02
# Ro_c                            3.711527e-02
# Руст                            3.129235e-02
# Руст                            3.046947e-02
# Дебит газа                      2.684438e-02
# Ro_g                            2.402379e-02
# Дебит гааз                      1.679479e-02
# Рпл. Тек (послед точка на КВД)  1.397142e-02
# Дебит кон нестабильный          1.259083e-02
# Рлин                            1.253106e-02
# Tлин                            1.017249e-02
# Дебит воды                      9.364072e-03
# Дебит воды                      8.456134e-03
# Рзаб                            6.258882e-03
# Pлин                            5.157324e-03
# Тна шлейфе                      4.999664e-03
# Рзаб                            4.080794e-03
# ...

# %%
plt.subplots(figsize=(25, 20))
hm = sns.heatmap(df.corr(),
                 cbar=True,
                 annot=True, annot_kws={'size':20}, linewidths=5, square=True, fmt=".1f",)

# %%
df_copy.describe()
# Out:
#        Глубина манометра        Dшт        Руст        Рзаб        Pлин  \
# count          93.000000  93.000000   93.000000   93.000000   93.000000
# mean         3524.086667  10.951183  228.293412  331.762255   99.860962
# std           142.099771   2.423172   41.897238   55.552713    7.300663
# min          3276.000000   6.350000  138.157895  174.000000   73.306638
# 25%          3437.000000   9.530000  201.636750  298.690000   95.945951
# 50%          3576.300000  11.110000  229.894737  336.700000  100.800000
# 75%          3650.000000  12.700000  252.000000  362.800000  103.865199
# max          3670.000000  15.880000  337.108108  458.600000  121.682930
#
#              Руст        Рзаб        Рлин       Туст  Тна шлейфе  ...  \
# count   93.000000   93.000000   93.000000  93.000000   93.000000  ...
# mean   227.644269  330.380503   98.005453  56.172043   43.091667  ...
# std     41.757127   55.431586   12.425851  11.250781   15.697842  ...
# ...

# %%
for column in df_copy.columns:
    plt.figure() 
    fig.suptitle(column)
    plt.boxplot(x=df_copy[column])
    plt.show()
