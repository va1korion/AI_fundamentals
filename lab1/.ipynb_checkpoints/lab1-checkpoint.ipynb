# %%
import numpy as np
import scipy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from termcolor import colored

# %%
# !pip install rfpimp
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: rfpimp in /home/va1korion/.local/lib/python3.8/site-packages (1.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from rfpimp) (1.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from rfpimp) (1.22.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from rfpimp) (3.5.2)
# Requirement already satisfied: scikit-learn in /home/va1korion/.local/lib/python3.8/site-packages (from rfpimp) (1.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->rfpimp) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->rfpimp) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->rfpimp) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->rfpimp) (4.33.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->rfpimp) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->rfpimp) (9.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->rfpimp) (3.0.8)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas->rfpimp) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/va1korion/.local/lib/python3.8/site-packages (from scikit-learn->rfpimp) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/va1korion/.local/lib/python3.8/site-packages (from scikit-learn->rfpimp) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->rfpimp) (1.8.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib->rfpimp) (1.14.0)
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: /usr/bin/python3 -m pip install --upgrade pip

# %%
df = pd.read_excel('data.xlsx', sheet_name='VU', skiprows=1, header=0)
df['КГФ_1'] = df['КГФ_1'].apply(lambda x: x*1000)
df['КГФ'] = df['КГФ'].mask(df['КГФ'].isna(), df['КГФ_1'])
df
# Out:
#        Номер Unnamed: 1 Глубина манометра    Dшт   Руст      Рзаб       Pлин  \
# 0        NaN        NaT               NaN    NaN    NaN       NaN        NaN
# 1      804.0 2008-06-05            3576.3   7.94  249.6     370.1      101.8
# 2      804.0 2008-06-06            3576.3   9.53  233.5     364.6      101.3
# 3      804.0 2008-06-07            3576.3  11.11  213.4     357.1      101.6
# 4      804.0 2008-06-08            3576.3  12.70  191.6     347.4       98.4
# ..       ...        ...               ...    ...    ...       ...        ...
# 181  22505.0 2009-09-23              3678  12.70  182.2   271.586  93.255111
# 182  22505.0 2009-09-27              3678  14.29  157.0   249.076  96.472143
# 183  22505.0 2010-04-09            3679.5   7.94  211.9  289.3877  91.131226
# 184  22505.0 2010-04-14            3679.5   9.53  204.0  282.8709  91.173008
# 185  22505.0 2010-04-17            3679.5  11.11  187.5  267.4787  91.530262
#
#      Руст.1 Рзаб.1        Рлин  ...  Рпл. Тек (Карноухов)   Pсб      Pсб.1  \
# 0       NaN    NaN         NaN  ...                   NaN   NaN        NaN
# 1     249.0  359.6       101.8  ...                     -  93.6  92.376018
# 2     231.0  338.1       102.4  ...                     -  92.9  91.685171
# 3     211.0  314.8       100.6  ...                     -  91.4  90.204787
# 4     187.0  291.5          99  ...                     -  89.2  88.033555
# ..      ...    ...         ...  ...                   ...   ...        ...
# 181   179.0  258.6   92.702141  ...                  60.8  89.7  88.527017
# 182   153.0  233.5  100.060417  ...                  60.8  87.3  86.158401
# 183   208.0  289.6   91.304642  ...                  61.3  88.2  87.046632
# 184   201.0  275.3   91.616821  ...                  61.3  88.5  87.342709
# 185   184.0    255   89.507935  ...                  61.3  89.8  88.625709
#
#          Ro_g   Ro_c    Ro_w  Удельная плотность газа    G_total       КГФ  \
# 0         NaN    NaN     NaN                       NaN       NaN       NaN
# 1    0.806017  801.0  1000.0                  0.669449  2.782623  311.9094
# 2    0.806017  801.0  1000.0                  0.669449  3.697781  288.6003
# 3    0.806017  801.0  1000.0                  0.669449  4.515073  248.7906
# 4    0.806017  801.0  1000.0                  0.669449  5.217673  223.5591
# ..        ...    ...     ...                       ...       ...       ...
# 181       NaN    NaN     NaN                       NaN       NaN       NaN
# 182       NaN    NaN     NaN                       NaN       NaN       NaN
# 183       NaN    NaN     NaN                       NaN       NaN       NaN
# 184       NaN    NaN     NaN                       NaN       NaN       NaN
# 185       NaN    NaN     NaN                       NaN       NaN       NaN
#
#     КГФ_1
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 181   NaN
# 182   NaN
# 183   NaN
# 184   NaN
# 185   NaN
#
# [186 rows x 34 columns]

# %%
del df["Номер"]
del df["КГФ_1"]
del df["Unnamed: 1"]
df.dropna(axis = 0, subset = ['G_total','КГФ'], how = 'all', inplace = True)
df=df.replace({'':np.NaN})
df=df.replace({'-':np.NaN})
df=df.replace({'не спускался':np.NaN})
df.dropna(thresh=55 ,axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93 entries, 1 to 168
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Глубина манометра               90 non-null     float64
#  1   Dшт                             93 non-null     float64
#  2   Руст                            93 non-null     float64
#  3   Рзаб                            90 non-null     float64
#  4   Pлин                            93 non-null     float64
#  5   Руст.1                          93 non-null     float64
#  6   Рзаб.1                          90 non-null     float64
#  7   Рлин                            93 non-null     float64
#  8   Туст                            93 non-null     float64
#  9   Тна шлейфе                      60 non-null     float64
#  10  Тзаб                            90 non-null     float64
#  11  Tлин                            93 non-null     float64
#  12  Дебит газа                      93 non-null     float64
#  13  Дебит ст. конд.                 93 non-null     float64
#  14  Дебит воды                      93 non-null     float64
#  15  Дебит смеси                     89 non-null     float64
#  16  Дебит гааз                      93 non-null     float64
#  17  Дебит кон нестабильный          93 non-null     float64
#  18  Дебит воды.1                    93 non-null     float64
#  19  Нэф                             93 non-null     float64
#  20  Рпл. Тек (послед точка на КВД)  88 non-null     float64
#  21  Рпл. Тек (Расчет по КВД)        81 non-null     float64
#  22  Рпл. Тек (Карноухов)            64 non-null     float64
#  23  Pсб                             93 non-null     float64
#  24  Pсб.1                           93 non-null     float64
#  25  Ro_g                            23 non-null     float64
#  26  Ro_c                            93 non-null     float64
#  27  Ro_w                            23 non-null     float64
#  28  Удельная плотность газа         93 non-null     float64
#  29  G_total                         23 non-null     float64
#  30  КГФ                             93 non-null     float64
# dtypes: float64(31)
# memory usage: 23.2 KB

# %%
for column in df.columns:
    df[column] = df[column].fillna((df[column].mean()))
df_copy = df.copy()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from rfpimp import permutation_importances

y_train = df_copy['КГФ']
del df_copy['КГФ']
y_train1 = df_copy['G_total']
del df_copy['G_total']
X_train = df_copy
rf = RandomForestRegressor(n_estimators = 100,
                           n_jobs = -1,
                           oob_score = True,
                           bootstrap = True,
                           random_state = 49)
rf.fit(X_train, y_train)

def r2(rf, X_train, y_train):
    return r2_score(y_train, rf.predict(X_train))

perm_imp_rfpimp = permutation_importances(rf, X_train, y_train, r2)
print(perm_imp_rfpimp)
# Out:
#                                 Importance
# Feature
# Рпл. Тек (послед точка на КВД)    0.734480
# Туст                              0.077923
# Дебит гааз                        0.053784
# Ro_c                              0.042144
# Рзаб                              0.024208
# Рпл. Тек (Расчет по КВД)          0.022771
# Руст.1                            0.022321
# Рзаб.1                            0.022001
# Дебит воды                        0.019044
# Глубина манометра                 0.009945
# Tлин                              0.006755
# Тзаб                              0.006538
# Дебит кон нестабильный            0.006491
# Дебит смеси                       0.006351
# Нэф                               0.006243
# Тна шлейфе                        0.006043
# Дебит газа                        0.005686
# Дебит воды.1                      0.005280
# Рлин                              0.005211
# Рпл. Тек (Карноухов)              0.005201
# Руст                              0.005056
# Удельная плотность газа           0.004621
# Ro_g                              0.003917
# Pсб                               0.003439
# Дебит ст. конд.                   0.003137
# Dшт                               0.003066
# Pлин                              0.002841
# Pсб.1                             0.002235
# Ro_w                              0.000000

# %%
plt.subplots(figsize=(25, 20))
hm = sns.heatmap(df.corr(),
                 cbar=True,
                 annot=True, annot_kws={'size':20}, linewidths=5, square=True, fmt=".1f",)

# %%
df_copy.describe()
# Out:
#        Глубина манометра        Dшт        Руст        Рзаб        Pлин  \
# count          93.000000  93.000000   93.000000   93.000000   93.000000
# mean         3524.086667  10.951183  228.293412  331.762255   99.860962
# std           142.099771   2.423172   41.897238   55.552713    7.300663
# min          3276.000000   6.350000  138.157895  174.000000   73.306638
# 25%          3437.000000   9.530000  201.636750  298.690000   95.945951
# 50%          3576.300000  11.110000  229.894737  336.700000  100.800000
# 75%          3650.000000  12.700000  252.000000  362.800000  103.865199
# max          3670.000000  15.880000  337.108108  458.600000  121.682930
#
#            Руст.1      Рзаб.1        Рлин       Туст  Тна шлейфе  ...  \
# count   93.000000   93.000000   93.000000  93.000000   93.000000  ...
# mean   227.644269  330.334444   98.005453  56.172043   43.091667  ...
# std     41.757127   55.431005   12.425851  11.250781   15.697842  ...
# min    136.000000  174.000000   40.739839  24.200000   14.000000  ...
# 25%    200.000000  296.800000   95.335032  50.300000   36.300000  ...
# 50%    228.000000  331.700000  100.260000  58.000000   43.091667  ...
# 75%    252.000000  359.900000  104.000000  64.000000   43.091667  ...
# max    333.000000  458.500000  123.616800  75.000000  110.200000  ...
#
#              Нэф  Рпл. Тек (послед точка на КВД)  Рпл. Тек (Расчет по КВД)  \
# count  93.000000                       93.000000                 93.000000
# mean   52.703325                       40.682881                 50.943684
# std    12.149424                        5.226271                  4.082894
# min    30.000000                       29.170000                 39.900000
# 25%    44.200000                       37.210000                 48.300000
# 50%    56.800000                       40.350000                 50.859600
# 75%    63.500000                       42.860000                 54.900000
# max    72.539800                       53.270000                 56.700000
#
#        Рпл. Тек (Карноухов)         Pсб       Pсб.1       Ro_g        Ro_c  \
# count             93.000000   93.000000   93.000000  93.000000   93.000000
# mean              50.773438   95.162366   93.917953   0.807631  780.847527
# std                3.315518    5.136060    5.068897   0.007372   62.795111
# min               41.600000   85.500000   84.381939   0.787416  186.000000
# 25%               50.100000   90.700000   89.513940   0.807631  782.000000
# 50%               50.773438   94.200000   92.968172   0.807631  787.000000
# 75%               51.700000   99.800000   98.494942   0.807631  793.700000
# max               56.800000  104.000000  102.640020   0.824330  801.000000
#
#          Ro_w  Удельная плотность газа
# count    93.0                 93.000000
# mean   1000.0                  0.665260
# std       0.0                  0.020485
# min    1000.0                  0.570000
# 25%    1000.0                  0.660000
# 50%    1000.0                  0.667000
# 75%    1000.0                  0.679000
# max    1000.0                  0.684660
#
# [8 rows x 29 columns]

# %%
C=len(df.columns)
L=len(df.index)
CN=df.count() #количество
NP=((L-CN)/L)*100 #процент пропущенных значений
MN=df.min() #минимум
Q1=df.quantile(q=0.25) #первый квартиль
MA=df.mean() #среднее значение
ME=df.median() #медиана
Q3=df.quantile(q=0.75) #третий квартиль
MX=df.max() #максимум
ST=df.std() #стандартное отклонение
P=df.nunique() #мощность
IQ=Q3-Q1 #интерквартильный размах
frame = pd.concat([CN, NP, MN, Q1, MA, ME, Q3, MX, ST, P, IQ], axis=1, join="inner")
frame=frame.T
f=pd.DataFrame(frame)
f.index=['Количество', 'Процент пропусков', 'Минимум', 'Первый квартиль','Среднее', 'Медиана', 'Третий квартиль', 'Максимум','Стандартное отклонение', 'Мощность', 'Интерквартильный размах']
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
f1=f.style.apply(lambda x: ["background-color:tomato" if i==1 else "" for i in x], axis=1, subset=(["Мощность"], slice(None))).apply(lambda x: ["background-color:tomato" if i>=60 else "" for i in x], axis=1, subset=(["Процент пропусков"], slice(None))).apply(lambda x: ["background-color:steelblue" if (i<30 and i>0) else "" for i in x], axis=1, subset=(["Процент пропусков"], slice(None))).apply(lambda x: ["background-color:limegreen" if i==0 else "" for i in x], axis=1, subset=(["Процент пропусков"], slice(None)))
f1
# Out:
# <style type="text/css">
# #T_c0ca6_row1_col0, #T_c0ca6_row1_col1, #T_c0ca6_row1_col2, #T_c0ca6_row1_col3, #T_c0ca6_row1_col4, #T_c0ca6_row1_col5, #T_c0ca6_row1_col6, #T_c0ca6_row1_col7, #T_c0ca6_row1_col8, #T_c0ca6_row1_col9, #T_c0ca6_row1_col10, #T_c0ca6_row1_col11, #T_c0ca6_row1_col12, #T_c0ca6_row1_col13, #T_c0ca6_row1_col14, #T_c0ca6_row1_col15, #T_c0ca6_row1_col16, #T_c0ca6_row1_col17, #T_c0ca6_row1_col18, #T_c0ca6_row1_col19, #T_c0ca6_row1_col20, #T_c0ca6_row1_col21, #T_c0ca6_row1_col22, #T_c0ca6_row1_col23, #T_c0ca6_row1_col24, #T_c0ca6_row1_col25, #T_c0ca6_row1_col26, #T_c0ca6_row1_col27, #T_c0ca6_row1_col28, #T_c0ca6_row1_col29, #T_c0ca6_row1_col30 {
#   background-color: limegreen;
# }
# #T_c0ca6_row9_col27 {
#   background-color: tomato;
# }
# </style>
# <table id="T_c0ca6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0ca6_level0_col0" class="col_heading level0 col0" >Глубина манометра</th>
#       <th id="T_c0ca6_level0_col1" class="col_heading level0 col1" >Dшт</th>
#       <th id="T_c0ca6_level0_col2" class="col_heading level0 col2" >Руст</th>
#       <th id="T_c0ca6_level0_col3" class="col_heading level0 col3" >Рзаб</th>
#       <th id="T_c0ca6_level0_col4" class="col_heading level0 col4" >Pлин</th>
#       <th id="T_c0ca6_level0_col5" class="col_heading level0 col5" >Руст.1</th>
#       <th id="T_c0ca6_level0_col6" class="col_heading level0 col6" >Рзаб.1</th>
#       <th id="T_c0ca6_level0_col7" class="col_heading level0 col7" >Рлин</th>
#       <th id="T_c0ca6_level0_col8" class="col_heading level0 col8" >Туст</th>
#       <th id="T_c0ca6_level0_col9" class="col_heading level0 col9" >Тна шлейфе</th>
#       <th id="T_c0ca6_level0_col10" class="col_heading level0 col10" >Тзаб</th>
#       <th id="T_c0ca6_level0_col11" class="col_heading level0 col11" >Tлин</th>
#       <th id="T_c0ca6_level0_col12" class="col_heading level0 col12" >Дебит газа</th>
#       <th id="T_c0ca6_level0_col13" class="col_heading level0 col13" >Дебит ст. конд.</th>
#       <th id="T_c0ca6_level0_col14" class="col_heading level0 col14" >Дебит воды</th>
#       <th id="T_c0ca6_level0_col15" class="col_heading level0 col15" >Дебит смеси</th>
#       <th id="T_c0ca6_level0_col16" class="col_heading level0 col16" >Дебит гааз</th>
#       <th id="T_c0ca6_level0_col17" class="col_heading level0 col17" >Дебит кон нестабильный</th>
#       <th id="T_c0ca6_level0_col18" class="col_heading level0 col18" >Дебит воды.1</th>
#       <th id="T_c0ca6_level0_col19" class="col_heading level0 col19" >Нэф</th>
#       <th id="T_c0ca6_level0_col20" class="col_heading level0 col20" >Рпл. Тек (послед точка на КВД)</th>
#       <th id="T_c0ca6_level0_col21" class="col_heading level0 col21" >Рпл. Тек (Расчет по КВД)</th>
#       <th id="T_c0ca6_level0_col22" class="col_heading level0 col22" >Рпл. Тек (Карноухов)</th>
#       <th id="T_c0ca6_level0_col23" class="col_heading level0 col23" >Pсб</th>
#       <th id="T_c0ca6_level0_col24" class="col_heading level0 col24" >Pсб.1</th>
#       <th id="T_c0ca6_level0_col25" class="col_heading level0 col25" >Ro_g</th>
#       <th id="T_c0ca6_level0_col26" class="col_heading level0 col26" >Ro_c</th>
#       <th id="T_c0ca6_level0_col27" class="col_heading level0 col27" >Ro_w</th>
#       <th id="T_c0ca6_level0_col28" class="col_heading level0 col28" >Удельная плотность газа </th>
#       <th id="T_c0ca6_level0_col29" class="col_heading level0 col29" >G_total</th>
#       <th id="T_c0ca6_level0_col30" class="col_heading level0 col30" >КГФ</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0ca6_level0_row0" class="row_heading level0 row0" >Количество</th>
#       <td id="T_c0ca6_row0_col0" class="data row0 col0" >93.000000</td>
#       <td id="T_c0ca6_row0_col1" class="data row0 col1" >93.000000</td>
#       <td id="T_c0ca6_row0_col2" class="data row0 col2" >93.000000</td>
#       <td id="T_c0ca6_row0_col3" class="data row0 col3" >93.000000</td>
#       <td id="T_c0ca6_row0_col4" class="data row0 col4" >93.000000</td>
#       <td id="T_c0ca6_row0_col5" class="data row0 col5" >93.000000</td>
#       <td id="T_c0ca6_row0_col6" class="data row0 col6" >93.000000</td>
#       <td id="T_c0ca6_row0_col7" class="data row0 col7" >93.000000</td>
#       <td id="T_c0ca6_row0_col8" class="data row0 col8" >93.000000</td>
#       <td id="T_c0ca6_row0_col9" class="data row0 col9" >93.000000</td>
#       <td id="T_c0ca6_row0_col10" class="data row0 col10" >93.000000</td>
#       <td id="T_c0ca6_row0_col11" class="data row0 col11" >93.000000</td>
#       <td id="T_c0ca6_row0_col12" class="data row0 col12" >93.000000</td>
#       <td id="T_c0ca6_row0_col13" class="data row0 col13" >93.000000</td>
#       <td id="T_c0ca6_row0_col14" class="data row0 col14" >93.000000</td>
#       <td id="T_c0ca6_row0_col15" class="data row0 col15" >93.000000</td>
#       <td id="T_c0ca6_row0_col16" class="data row0 col16" >93.000000</td>
#       <td id="T_c0ca6_row0_col17" class="data row0 col17" >93.000000</td>
#       <td id="T_c0ca6_row0_col18" class="data row0 col18" >93.000000</td>
#       <td id="T_c0ca6_row0_col19" class="data row0 col19" >93.000000</td>
#       <td id="T_c0ca6_row0_col20" class="data row0 col20" >93.000000</td>
#       <td id="T_c0ca6_row0_col21" class="data row0 col21" >93.000000</td>
#       <td id="T_c0ca6_row0_col22" class="data row0 col22" >93.000000</td>
#       <td id="T_c0ca6_row0_col23" class="data row0 col23" >93.000000</td>
#       <td id="T_c0ca6_row0_col24" class="data row0 col24" >93.000000</td>
#       <td id="T_c0ca6_row0_col25" class="data row0 col25" >93.000000</td>
#       <td id="T_c0ca6_row0_col26" class="data row0 col26" >93.000000</td>
#       <td id="T_c0ca6_row0_col27" class="data row0 col27" >93.000000</td>
#       <td id="T_c0ca6_row0_col28" class="data row0 col28" >93.000000</td>
#       <td id="T_c0ca6_row0_col29" class="data row0 col29" >93.000000</td>
#       <td id="T_c0ca6_row0_col30" class="data row0 col30" >93.000000</td>
#     </tr>
#     <tr>
#       <th id="T_c0ca6_level0_row1" class="row_heading level0 row1" >Процент пропусков</th>
#       <td id="T_c0ca6_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_c0ca6_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_c0ca6_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_c0ca6_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_c0ca6_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_c0ca6_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_c0ca6_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_c0ca6_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_c0ca6_row1_col8" class="data row1 col8" >0.000000</td>
#       <td id="T_c0ca6_row1_col9" class="data row1 col9" >0.000000</td>
#       <td id="T_c0ca6_row1_col10" class="data row1 col10" >0.000000</td>
#       <td id="T_c0ca6_row1_col11" class="data row1 col11" >0.000000</td>
#       <td id="T_c0ca6_row1_col12" class="data row1 col12" >0.000000</td>
#       <td id="T_c0ca6_row1_col13" class="data row1 col13" >0.000000</td>
#       <td id="T_c0ca6_row1_col14" class="data row1 col14" >0.000000</td>
#       <td id="T_c0ca6_row1_col15" class="data row1 col15" >0.000000</td>
#       <td id="T_c0ca6_row1_col16" class="data row1 col16" >0.000000</td>
#       <td id="T_c0ca6_row1_col17" class="data row1 col17" >0.000000</td>
#       <td id="T_c0ca6_row1_col18" class="data row1 col18" >0.000000</td>
#       <td id="T_c0ca6_row1_col19" class="data row1 col19" >0.000000</td>
#       <td id="T_c0ca6_row1_col20" class="data row1 col20" >0.000000</td>
#       <td id="T_c0ca6_row1_col21" class="data row1 col21" >0.000000</td>
#       <td id="T_c0ca6_row1_col22" class="data row1 col22" >0.000000</td>
#       <td id="T_c0ca6_row1_col23" class="data row1 col23" >0.000000</td>
#       <td id="T_c0ca6_row1_col24" class="data row1 col24" >0.000000</td>
#       <td id="T_c0ca6_row1_col25" class="data row1 col25" >0.000000</td>
#       <td id="T_c0ca6_row1_col26" class="data row1 col26" >0.000000</td>
#       <td id="T_c0ca6_row1_col27" class="data row1 col27" >0.000000</t

# %%
for i in df_copy.columns:
    plt.figure(i)
    sns.histplot(df[i],kde=True,stat="density")
    plt.axvline(f.iloc[3][i]-1.5*f.iloc[10]["Dшт"], color="indigo", ls='--') #q1-1.5*iqr
    plt.axvline(f.iloc[3][i], color="dodgerblue", ls='--') #первый квартиль
    plt.axvline(f.iloc[4][i], color="red", ls='--') #среднее
    plt.axvline(f.iloc[5][i], color="goldenrod", ls='--') #медиана
    plt.axvline(f.iloc[6][i], color="dodgerblue", ls='--') #третий квартиль
    plt.axvline(f.iloc[6][i]+1.5*f.iloc[10][i], color="indigo", ls='--') #q3+1.5*iqr
    plt.show()

# %%
sns.histplot(df[df.columns[25]],kde=True,stat="density")
plt.axvline(f.iloc[3][df.columns[25]], color="dodgerblue", ls='--') #первый квартиль
plt.axvline(f.iloc[4][df.columns[25]], color="red", ls='--') #среднее
plt.axvline(f.iloc[5][df.columns[25]], color="goldenrod", ls='--') #медиана
plt.axvline(f.iloc[6][df.columns[25]], color="dodgerblue", ls='--') #третий квартиль
